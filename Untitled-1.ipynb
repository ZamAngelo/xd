# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import seaborn as sb 
import yfinance as yf

# %%
act = ['CHDRAUIB.MX',"NVTA.MX", 'VOLARA.MX']

df = pd.DataFrame

def extrac(activos,inicio,final):
    dff=yf.download(activos,start=inicio,end=final)["Adj Close"]
    return dff

# %%
df=extrac(act,"2022-01-01","2023-01-01")
df
# Out:
# [*********************100%%**********************]  3 of 3 completed
#             CHDRAUIB.MX     NVTA.MX  VOLARA.MX
# Date
# 2022-01-03    41.917473  300.000000  36.360001
# 2022-01-04    43.085396  290.000000  36.250000
# 2022-01-05    42.427826  290.000000  36.139999
# 2022-01-06    41.937103  267.000000  35.990002
# 2022-01-07    40.739742  260.000000  37.790001
# ...                 ...         ...        ...
# 2022-12-26    83.479645   37.000000  16.940001
# 2022-12-27    84.163666   33.500000  16.520000
# 2022-12-28    83.757217   34.000000  15.590000
# 2022-12-29    82.299965   35.630001  16.299999
# 2022-12-30    82.299965   36.000000  16.230000
#
# [252 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
import seaborn as sns

# %%
sns.pairplot(df)
